# %% [markdown]
# # Boston Airbnb Take home assgnments
#
# This dataset was obtained from [Kaggle](https://www.kaggle.com/datasets/airbnb/boston)
#
# The following Airbnb activity is included in this Boston dataset:
#
#  - Listings, including full descriptions and average review score
#  - Reviews, including unique id for each reviewer and detailed comments
#  - Calendar, including listing id and the price and availability for that day
#
# ## Please complete the following 9 questions based on cleaned listings data. Create proper visualization for each question (except question 9) and briefly discuss the result/findings of your data analysis at the end.
#
# 1. What is overall review score rating distribution? Create a histogram based on the review score rating
# 2. List top 5 neighbourhood that have the best review scores rating
# 3. Do listings that accommodate more guests have high review score? Disaply average review scores rating by number of accommodate.
# 4. List top 10 amenities that have the highest average review score rating.
# 5. Display top 5 property type that has the highest average review rating.
# 6. Modify the above query to display top 5 property type that has the highest average review rating. However, limit the result to the property having at least 20 listings.
# 7. What is correlation between price and all review metrics?
# 8. Display top 10 neighbourhood that have the best location review scores?
# 9. for the top 10 neighbourhood that have the best location review scores, display number of listing, average price and average review rating. Sort by number of listing in decending order.
#
# **Write a paragraph to disucss the finding of your data analysis result at the end.**

# %% [markdown]
# # Import packages and airbnb datasets
#
# Make sure you choose Conda Environment AI500Env

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

#ignore warnings message
warnings.filterwarnings("ignore")

# %%
# read listings data

df=pd.read_csv('listings_cleaned.csv')

# %%
df.columns

# %%
df.shape

# %% [markdown]
# ## What is overall review score rating distribution? Create a histogram based on the review score rating

# %% [markdown]
# ## List top 5 neighbourhood that have the best review scores rating

# %% [markdown]
# ## Do listings that accommodate more guests have high review score? Disaply average review scores rating by number of accommodate.

# %% [markdown]
# ## List top 10 amenities that have the highest average review score rating

# %% [markdown]
# ## Display top 5 property type that has the highest average review rating

# %% [markdown]
# ## Modify the above query to display top 5 property type that has the highest average review rating. However, limit the result to the property having at least 20 listings.

# %% [markdown]
# ## What is correlation between price and all review metrics?
# hint: use corr()

# %% [markdown]
# ## Display top 10 neighbourhood that have the best location review scores?

# %% [markdown]
# ## for the top 10 neighbourhood that have the best location review scores, display number of listing, average price and average review rating. Sort by number of listing in decending order.
# Note: No need to create a visualization for this question

# %% [markdown]
# # Write a paragraph to disucss the finding of your data analysis result.
