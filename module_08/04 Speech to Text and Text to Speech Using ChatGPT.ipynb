# %% [markdown]
# ## [Speech to Text](https://platform.openai.com/docs/guides/speech-to-text)

# %%
from openai import OpenAI
import base64
from dotenv import load_dotenv
import os
import requests
import datetime
import re
import IPython
from PIL import Image

# define the environment path. it is at the parent folder
env_path ="../.env"
load_dotenv(dotenv_path=env_path, override=True)

api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI()

# %%
audio_file= open("audio/data_role_in_ai.m4a", "rb")

transcription = client.audio.transcriptions.create(
    model="gpt-4o-transcribe", 
    file=audio_file
)

print(transcription.text)
# Out:
# Welcome to The Deep Dive, your shortcut to being truly well-informed. Today, we're getting stuck into data, which is, well, it's the absolute fuel for AI. It really is. And it's kind of funny sometimes how even the huge tech companies can really mess it up spectacularly. Oh, yeah. Remember Pinterest? They accidentally sent out this mass email saying you're getting married to tons of users who are, you know, already married. A bit awkward. Yeah, a very awkward digital moment, you could say. And that's honestly just the tip of the iceberg. You think about Target, their system got so clever using shopping data, things like unscented lotions and stuff. It actually predicted a teenager was pregnant, accurately predicted it. Before she'd even told her own dad. Exactly. He found out from the coupons they sent. So these aren't just like funny stories. They really highlight how powerful, but also how incredibly sensitive this data actually is. Absolutely. And those examples really set the stage for what we want to do today, which is to unpack this idea of data, the fuel for AI. What is this fuel exactly? Why is it so important? And maybe crucially, what are the pitfalls we need to watch out for to make AI genuinely smart, useful and ethical? Yeah, the ethical part is huge. So consider this your express ticket to understanding the engine, you know, the thing humming behind all this artificial intelligence stuff. Now, when we talk data, we're not just talking a few files here and there. It's a flood, a real deluge. Oh, absolutely. Google alone processes something like what, over 40,000 searches every single second. Mind boggling numbers. It really is. And they reckon that by 2025, the amount of data created globally will hit 163 zettabytes. I mean, I can't even picture that number. It's astronomical. And it's not just our stuff like photos and emails. It's machine data, data from all those IoT sensors, Internet of Things devices. Billions of them. Yeah, like 12.86 billion back in 2020, apparently. Just tiny things constantly collecting real time data. And that immense scale, that's exactly what we mean by big data. It's often defined by its initial three Vs. First, you've got volume, just the sheer scale, often tens of terabytes, like 500 hours of movies. That's about one terabyte. So massive amounts. Then there's variety, the incredible mix of data types, web pages, social media, biometric scans, all those IoT sensors we mentioned. It's all over the place. And third is velocity, the speed it's all created. Just think like 4.1 million YouTube videos watched every single minute. Incredible speed. But for AI specifically, there are a couple more Vs that are really vital. Veracity is the data actually accurate. True. Because biased data leads to biased AI. Garbage in, garbage out, right? Precisely. And value. Does this data actually help answer the business question you have? Or is your AI just going to find patterns in, well, noise? That's a great point. So you need truthfulness and relevance too. So within all that volume and variety, not all data is the same for AI, is it? Not at all. About 20% of AI projects, roughly, use structured data. That's the neat stuff. Like spreadsheets? Exactly. Spreadsheets, databases, financial records, addresses, stuff that's organized. It's, well, easier to work with. Makes sense. But the vast majority, maybe 80% or more, deal with unstructured data. And that's the messy stuff. That's the messy stuff. Images, videos, audio files, emails, social media posts, no predefined format. It can be tedious to manage. But that's where the value often lies, isn't it? Very often. Because it doesn't have that predefined order, AI has to find the patterns. That's how you get breakthroughs in image recognition or understanding language. Interesting. And then there's a bit in the middle, maybe 5-10%, called semi-structured data. Think like web data, XML, JSON. It has tags, some internal organization, but it's not a neat ta ...

# %% [markdown]
# ## Text to Speech

# %%
trasncript_chunk=transcription.text[:500]

# %%
from pathlib import Path
from openai import OpenAI

speech_file_path="audio/data_role_coral.mp3"

with client.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice="coral",
    input=trasncript_chunk,
    instructions="Speak in a cheerful and positive tone.",
) as response:
    response.stream_to_file(speech_file_path)

# %% [markdown]
# Play generated audio

# %%
from IPython.display import Audio

# Play an MP3 file
Audio("audio/data_role_coral.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Change to another voice:
#
# Openai Current offer the following voice:
# - alloy
# - ash
# - ballad
# - coral
# - echo
# - fable
# - nova
# - onyx
# - sage
# - shimmer

# %%
speech_file_path="audio/data_role_nova.mp3"

with client.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice="nova",
    #input=transcription.text,
    input=trasncript_chunk,
    instructions="Speak in a cheerful and positive tone.",
) as response:
    response.stream_to_file(speech_file_path)
    
Audio("audio/data_role_nova.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
